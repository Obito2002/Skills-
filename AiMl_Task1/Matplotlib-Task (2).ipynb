# %% [markdown]
# # Data Visualization with Matplotlib

# %% [markdown]
# RUN THE CELL BELOW AND START SOLVING

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# Plot (x,y) axes and set the labels and titles <br>
# Use ax.plot function to plot a simple sinusoid to match the plot below <br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
x = np.arange(0, 10,0.1 )
y = np.sin(x)
plt.plot(x, y)

# %%
# your code here

# %% [markdown]
# Use Scatter Plots to draw below as the given output <br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
x = np.arange(0, 10,0.3 )
y = np.sin(x)
plt.scatter(x, y)

# %%
# your code here-

# %% [markdown]
# use line and color codes to plot points along with a line connecting them<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
x = np.arange(0, 10,0.3 )
y = np.sin(x)
plt.plot(x, y,marker='o')

# %%
#your code here-

# %% [markdown]
# create a single figure with multiple lines as follows<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
x = np.arange(0, 10,0.1 )
y = np.sin(x)
plt.plot(x, y)
x2=np.arange(0,10,0.1)
y2=np.sin(x+1.57)
plt.plot(x2,y2)

# %%
# your code here-

# %% [markdown]
# Create the plot given below in the output by using 'linestyle'  keyword.<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
x=np.arange(0,10)
y=x
plt.plot(x,y)
y2= x+1
plt.plot(x, y2, color='orange', linestyle='dashed')

y3= x+2
plt.plot(x, y3, color='green', linestyle='dashdot')

y4= x+3
plt.plot(x, y4, color='red', linestyle='dotted')

y5= x+4
plt.plot(x, y5, color='purple')

y6= x+5
plt.plot(x, y6, color='brown', linestyle='dashed')

y7= x+6
plt.plot(x, y7, color='magenta', linestyle='dashdot')

y8= x+7
plt.plot(x, y8, color='grey', linestyle='dotted')

# %%
# your code here-

# %% [markdown]
# use 'linestyle' and 'color' keyword  to draw as given below in the output<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
x=np.arange(0,10)
y=x
plt.plot(x,y,color="green")
y2= x+1
plt.plot(x, y2, color='cyan', linestyle='dashed')

y3= x+2
plt.plot(x, y3, color='purple', linestyle='dashdot')

y4= x+3
plt.plot(x, y4, color='red', linestyle='dotted')

# %%
# your code here-

# %% [markdown]
# # GOOD JOB!!
